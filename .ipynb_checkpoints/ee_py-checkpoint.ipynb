# %%
import ee
import geopandas as gpd
import pandas as pd
import pandas as pd
import json

# %%
ee.Authenticate()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=W9rOuLT91C3vme9zILmXXFAUW_96i4AEtBI1seG-YWg&tc=d-2oqw7JX8iZlB3Lip1JrEumodU66xqspll1rHXz4SM&cc=sdAOW7awcRKY9xaN62fasSmvJtSsPlhPjsbJHTGLf78>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=W9rOuLT91C3vme9zILmXXFAUW_96i4AEtBI1seG-YWg&tc=d-2oqw7JX8iZlB3Lip1JrEumodU66xqspll1rHXz4SM&cc=sdAOW7awcRKY9xaN62fasSmvJtSsPlhPjsbJHTGLf78</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Enter verification code: 4/1AVHEtk6kBtUTaBAgPp1DGVlHhtyTaVupCBgGK8u2KjHMDUtxbs3M1UjlIkU
#
# Successfully saved authorization token.

# %%
ee.Initialize()

# %%
data = ee.ImageCollection("IDAHO_EPSCOR/TERRACLIMATE");

# %%
dataset = data.filterDate('2018-5-1', '2020-5-30')

# %%
total = dataset.reduce(ee.Reducer.sum());

# %%
ranchi = gpd.read_file("./ranchi/ranchi_new.shp")

# %%
js = json.loads(ranchi.to_json())
shpz = ee.Geometry(ee.FeatureCollection(js).geometry())

# %%
stats = total.reduceRegion(
  reducer= ee.Reducer.mean(),
  geometry= shpz,
  scale= 5000,
  )

# %%
print("Amount = ",stats.get('pr_sum').getInfo())
# Out:
# Amount =  3038.7696670059636

# %%
count = total.reduceRegion(
  reducer= ee.Reducer.count(),
  geometry= shpz,
  scale= 5000,
  )

# %%
print("Total Pixel = ", count.get('pr_sum').getInfo())
# Out:
# Total Pixel =  215

# %%
totalRanchi = total.clip(shpz)


vectors = totalRanchi.sampleRegions(
  collection=shpz,
  geometries= True,
  scale= 5000,
)
# Out:
# <class 'dict'>
# {'type': 'FeatureCollection', 'columns': {}, 'properties': {'band_order': ['aet_sum', 'def_sum', 'pdsi_sum', 'pet_sum', 'pr_sum', 'ro_sum', 'soil_sum', 'srad_sum', 'swe_sum', 'tmmn_sum', 'tmmx_sum', 'vap_sum', 'vpd_sum', 'vs_sum']}, 'features': [{'type': 'Feature', 'geometry': {'geodesic': False, 'type': 'Point', 'coordinates': [85.85648327972326, 22.88458186294481]}, 'id': '0_0', 'properties': {'aet_sum': 18808, 'def_sum': 10610, 'pdsi_sum': 4054, 'pet_sum': 29418, 'pr_sum': 3150, 'ro_sum': 1271, 'soil_sum': 28375, 'srad_sum': 51138, 'swe_sum': 0, 'tmmn_sum': 4830, 'tmmx_sum': 7705, 'vap_sum': 50723, 'vpd_sum': 3426, 'vs_sum': 3330}}, {'type': 'Feature', 'geometry': {'geodesic': False, 'type': 'Point', 'coordinates': [85.63190445869338, 22.929497627150784]}, 'id': '0_1', 'properties': {'aet_sum': 18499, 'def_sum': 10726, 'pdsi_sum': 3749, 'pet_sum': 29225, 'pr_sum': 3104, 'ro_sum': 1252, 'soil_sum': 28731, 'srad_sum': 51122, 'swe_sum': 0, 'tmmn_sum': 4759, 'tmmx_sum': 7650, 'vap_sum': 49591, 'vpd_sum': 3403, 'vs_sum': 3310}}, {'type': 'Feature', 'geometry': {'geodesic': False, 'type': 'Point', 'coordinates': [85.81156751551728, 22.929497627150784]}, 'id': '0_2', 'properties': {'aet_sum': 18780, 'def_sum': 10815, 'pdsi_sum': 4065, 'pet_sum': 29595, 'pr_sum': 3129, 'ro_sum': 1252, 'soil_sum': 27986, 'srad_sum': 51211, 'swe_sum': 0, 'tmmn_sum': 4842, 'tmmx_sum': 7723, 'vap_sum': 50627, 'vpd_sum': 3469, 'vs_sum': 3400}}, {'type': 'Feature', 'geometry': {'geodesic': False, 'type': 'Point', 'coordinates': [85.85648327972326, 22.929497627150784]}, 'id': '0_3', 'properties': {'aet_sum': 18708, 'def_sum': 11313, 'pdsi_sum': 4026, 'pet_sum': 30021, 'pr_sum': 3086, 'ro_sum': 1218, 'soil_sum': 27507, 'srad_sum': 51339, 'swe_sum': 0, 'tmmn_sum': 4914, 'tmmx_sum': 7811, 'vap_sum': 51516, 'vpd_sum': 3547, 'vs_sum': 3500}}, {'type': 'Feature', 'geometry': {'geodesic': False, 'type': 'Point', 'coordinates': [85.63190445869338, 22.974413391356762]}, 'id': '0_4', 'properties': {'aet_sum': 18091, 'def_sum': 12246, 'pdsi_sum': 3641, 'pet_sum': 30337, 'pr_sum': 2862, 'ro_sum': 1049, 'soil_sum': 26755, 'srad_sum': 51426, 'swe_sum': 0, 'tmmn_sum': 5034, 'tmmx_sum': 7975, 'vap_sum': 53158, 'vpd_sum': 3689, 'vs_sum': 3450}}, {'type': 'Feature', 'geometry': {'geodesic': False, 'type': 'Point', 'coordinates': [85.67682022289937, 22.974413391356762]}, 'id': '0_5', 'properties': {'aet_sum': 18180, 'def_sum': 11967, 'pdsi_sum': 3841, 'pet_sum': 30147, 'pr_sum': 2896, 'ro_sum': 1079, 'soil_sum': 26854, 'srad_sum': 51384, 'swe_sum': 0, 'tmmn_sum': 5013, 'tmmx_sum': 7949, 'vap_sum': 52797, 'vpd_sum': 3673, 'vs_sum': 3390}}, {'type': 'Feature', 'geometry': {'geodesic': False, 'type': 'Point', 'coordinates': [85.72173598710533, 22.974413391356762]}, 'id': '0_6', 'properties': {'aet_sum': 18238, 'def_sum': 11997, 'pdsi_sum': 3873, 'pet_sum': 30235, 'pr_sum': 2905, 'ro_sum': 1081, 'soil_sum': 26696, 'srad_sum': 51406, 'swe_sum': 0, 'tmmn_sum': 5037, 'tmmx_sum': 7965, 'vap_sum': 53025, 'vpd_sum': 3694, 'vs_sum': 3420}}, {'type': 'Feature', 'geometry': {'geodesic': False, 'type': 'Point', 'coordinates': [85.76665175131131, 22.974413391356762]}, 'id': '0_7', 'properties': {'aet_sum': 18246, 'def_sum': 12109, 'pdsi_sum': 4058, 'pet_sum': 30355, 'pr_sum': 2917, 'ro_sum': 1094, 'soil_sum': 26610, 'srad_sum': 51420, 'swe_sum': 0, 'tmmn_sum': 5043, 'tmmx_sum': 7973, 'vap_sum': 53107, 'vpd_sum': 3706, 'vs_sum': 3450}}, {'type': 'Feature', 'geometry': {'geodesic': False, 'type': 'Point', 'coordinates': [85.81156751551728, 22.974413391356762]}, 'id': '0_8', 'properties': {'aet_sum': 18235, 'def_sum': 12167, 'pdsi_sum': 4019, 'pet_sum': 30402, 'pr_sum': 2906, 'ro_sum': 1082, 'soil_sum': 26494, 'srad_sum': 51481, 'swe_sum': 0, 'tmmn_sum': 5075, 'tmmx_sum': 8005, 'vap_sum': 53569, 'vpd_sum': 3732, 'vs_sum': 3420}}, {'type': 'Feature', 'geometry': {'geodesic': False, 'type': 'Point', 'coordinates': [84.95816799560374, 23.019329155562737]}, 'id': '0_9', 'properties': {'aet_sum': ...

# %%
task_config = {
  'collection': vectors,
  'folder': 'earthengine_all',
  'fileNamePrefix': 'vec_',
  'fileFormat': 'CSV'}

task=ee.batch.Export.table.toDrive(**task_config)
task.start()
